# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('covidMO.csv')

# %%
df[['year', 'month']] = df['case_month'].str.split('-', 1, expand=True)

# %%
df=df.drop(['res_state','state_fips_code','case_positive_specimen_interval','case_onset_interval','current_status','process','exposure_yn'], axis=1)

# %%
df.head()
# Out:
#   case_month  res_county  county_fips_code       age_group     sex race  \
# 0    2021-07     LACLEDE             29105  50 to 64 years     NaN  NaN
# 1    2022-01      PHELPS             29161    0 - 17 years  Female  NaN
# 2    2020-08  WASHINGTON             29221    0 - 17 years  Female  NaN
# 3    2020-06     AUDRAIN             29007  18 to 49 years  Female  NaN
# 4    2021-07    LAWRENCE             29109  18 to 49 years    Male  NaN
#
#   ethnicity symptom_status  hosp_yn   icu_yn death_yn  \
# 0       NaN    Symptomatic  Unknown  Missing      NaN
# 1       NaN        Missing  Unknown  Missing  Unknown
# 2       NaN        Missing  Unknown  Missing  Unknown
# 3       NaN    Symptomatic  Unknown  Missing  Unknown
# 4       NaN        Missing  Unknown  Missing  Unknown
#
#   underlying_conditions_yn  year month
# 0                      NaN  2021    07
# 1                      NaN  2022    01
# 2                      NaN  2020    08
# 3                      NaN  2020    06
# ...

# %%
df.to_csv('covidMOclean.csv',index=False)

# %%
for col in df.columns:
    display(df[col].value_counts(dropna=False))
# Out:
# GREENE            53908
# JACKSON           51832
# JEFFERSON         44763
# BOONE             36257
# CLAY              20587
# CASS              19557
# COLE              18135
# FRANKLIN          17873
# BUCHANAN          17022
# JASPER            16257
# CHRISTIAN         15276
# CAPE GIRARDEAU    14518
# LINCOLN           11104
# CALLAWAY          10524
# TANEY             10159
# PETTIS             9599
# NEWTON             9124
# SCOTT              8901
# JOHNSON            8777
# PHELPS             8170
# CAMDEN             7718
# PLATTE             7575
# BUTLER             6891
# WEBSTER            6841
# LACLEDE            6577
# PULASKI            6563
# HOWELL             6297
# LAFAYETTE          5873
# WARREN             5601
# LAWRENCE           5518
# DUNKLIN            5378
# MILLER             5084
# STODDARD           4823
# NODAWAY            4666
# HENRY              4654
# MARION             4472
# STONE              4421
# SALINE             4406
# ...

# %%
new = df.drop(['res_state', 'state_fips_code', 'case_positive_specimen_interval', 'case_onset_interval', 'current_status', 'process'], axis=1)

# %%
new
# Out:
#         case_month   res_county  county_fips_code       age_group     sex  \
# 0          2020-11       SHASTA              6089  18 to 49 years  Female
# 1          2020-12       MADERA              6039  18 to 49 years    Male
# 2          2021-01       NEVADA              6057    0 - 17 years  Female
# 3          2021-12    DEL NORTE              6015  18 to 49 years  Female
# 4          2021-07    MENDOCINO              6045  18 to 49 years  Female
# ...            ...          ...               ...             ...     ...
# 4376602    2021-01  LOS ANGELES              6037  18 to 49 years    Male
# 4376603    2021-01  LOS ANGELES              6037  18 to 49 years    Male
# 4376604    2021-01  LOS ANGELES              6037  18 to 49 years    Male
# 4376605    2021-01  LOS ANGELES              6037  18 to 49 years    Male
# 4376606    2021-01  LOS ANGELES              6037  18 to 49 years    Male
#
#                    race            ethnicity exposure_yn symptom_status  \
# ...

# %%
df['state_fips_code'].value_counts()
# Out:
# 6    4376607
# Name: state_fips_code, dtype: int64

# %%
df.memory_usage(index=True).sum()
# Out:
# 665244392

# %%
new.memory_usage(index=True)
# Out:
# Index                            128
# case_month                  35012856
# res_county                  35012856
# county_fips_code            35012856
# age_group                   35012856
# sex                         35012856
# race                        35012856
# ethnicity                   35012856
# exposure_yn                 35012856
# symptom_status              35012856
# hosp_yn                     35012856
# icu_yn                      35012856
# death_yn                    35012856
# underlying_conditions_yn    35012856
# dtype: int64

# %%
new.to_csv('clean_data.csv',index=False)

# %%
new['age_group'].value_counts()
# Out:
# 18 to 49 years    2358096
# 0 - 17 years       839675
# 50 to 64 years     748748
# 65+ years          423489
# Missing              1265
# Name: age_group, dtype: int64

# %%
ages ={'0 - 17 years':0,
       '18 to 49 years':1,
       '50 to 64 years':2,
      '65+ years':3,
      'Missing':-1,
       np.nan:-1
      }

# %%
new['age_group']=new['age_group'].replace(ages).astype(int)

# %%
new['age_group'].value_counts(dropna=False)
# Out:
#  1    2358096
#  0     839675
#  2     748748
#  3     423489
# -1       6599
# Name: age_group, dtype: int64

# %%
new
# Out:
#         case_month   res_county  county_fips_code  age_group     sex  \
# 0          2020-11       SHASTA              6089          1  Female
# 1          2020-12       MADERA              6039          1    Male
# 2          2021-01       NEVADA              6057          0  Female
# 3          2021-12    DEL NORTE              6015          1  Female
# 4          2021-07    MENDOCINO              6045          1  Female
# ...            ...          ...               ...        ...     ...
# 4376602    2021-01  LOS ANGELES              6037          1    Male
# 4376603    2021-01  LOS ANGELES              6037          1    Male
# 4376604    2021-01  LOS ANGELES              6037          1    Male
# 4376605    2021-01  LOS ANGELES              6037          1    Male
# 4376606    2021-01  LOS ANGELES              6037          1    Male
#
#                    race            ethnicity exposure_yn symptom_status  \
# ...

# %%
new.to_csv('clean_data1.csv',index=False)
